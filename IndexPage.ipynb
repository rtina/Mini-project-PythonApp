# %%
from tkinter import *
from tkinter.ttk import *
from tkinter import Button
from tkinter import messagebox
import sqlite3
import tkinter as tk
from tkinter import StringVar

window = Tk()
window.title("Selection Window")
window.geometry('500x500')
window.resizable(False, False)
window.configure(bg="#9AD7A4")
global index


def Quiz():
    global index,correct
    root = tk.Tk()
    root.geometry('500x500')
    
    questions = ["Which is known as Yoga Capital of India?",
                 "Named after a famous British hunter turned naturalist, what is the name of India’s first national park?",
                 "BRIC includes Russia, India, China and----------",
                 " Which of these is a heritage & historical monument of Pink City – Jaipur?",
                 "When does India celebrate National Tourism Day"]
    
    
    options = [['Haridwar, Uttarakhand','Varanasi,Uttar Pradesh','Dharamshala,Himachal Pradesh','Rishikesh, Uttarakhand','Rishikesh, Uttarakhand'],
               ['Jim Corbett National Park','Nokrek National Park','Murlen National Park','Mount Harriet National Park','Jim Corbett National Park'],
               ['Bharma','Brazil','Bangladesh','None of these','Brazil'],
               ['Umaid Bhawan Palace','Mehrangarh Fort','Hawa Mahal','Patwon Ki Haveli','Umaid Bhawan Palace'],
               ['6th October','3rd December','21st March','25th January','25th January']]
    
    
    frame = tk.Frame(root, padx=10, pady=10,bg='#fff')
    question_label = tk.Label(frame,height=5, width=28,bg='grey',fg="#fff", 
                              font=('Verdana', 20),wraplength=500)
    
    
    v1 = StringVar(frame)
    v2 = StringVar(frame)
    v3 = StringVar(frame)
    v4 = StringVar(frame)
    
    option1 = tk.Radiobutton(frame, bg="#fff", variable=v1, font=('Verdana', 20),
                             command = lambda : checkAnswer(option1))
    option2 = tk.Radiobutton(frame, bg="#fff", variable=v2, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option2))
    option3 = tk.Radiobutton(frame, bg="#fff", variable=v3, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option3))
    option4 = tk.Radiobutton(frame, bg="#fff", variable=v4, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option4))
    
    button_next = tk.Button(frame, text='Next',bg='yellow', font=('Verdana', 20), 
                            command = lambda : displayNextQuestion())
    
    frame.pack(fill="both", expand="true")
    question_label.grid(row=0, column=0)
    
    option1.grid(sticky= 'W', row=1, column=0)
    option2.grid(sticky= 'W', row=2, column=0)
    option3.grid(sticky= 'W', row=3, column=0)
    option4.grid(sticky= 'W', row=4, column=0)
    
    button_next.grid(row=6, column=0)
    
    
    index = 0
    correct = 0
    
    # create a function to disable radiobuttons
    def disableButtons(state):
        option1['state'] = state
        option2['state'] = state
        option3['state'] = state
        option4['state'] = state
    
    # create a function to check the selected answer
    def checkAnswer(radio):
        global correct, index
        
        # the 4th item is the correct answer
        # we will check the user selected answer with the 4th item
        if radio['text'] == options[index][4]:
            correct +=1
    
        index +=1
        disableButtons('disable')
    
    
    # create a function to display the next question
    def displayNextQuestion():
        global correct,index
    
        if button_next['text'] == 'Restart The Quiz':
            correct = 0
            index = 0
            question_label['bg'] = 'grey'
            button_next['text'] = 'Next'
    
        if index == len(options):
           question_label['text'] = str(correct) + " / " + str(len(options))
           button_next['text'] = 'Restart The Quiz'
           if correct >= len(options)/2:
               question_label['bg'] = 'green'
           else:
                question_label['bg'] = 'red'
    
        else:
            question_label['text'] = questions[index]
            
            disableButtons('normal')
            opts = options[index]
            option1['text'] = opts[0]
            option2['text'] = opts[1]
            option3['text'] = opts[2]
            option4['text'] = opts[3]
            v1.set(opts[0])
            v2.set(opts[1])
            v3.set(opts[2])
            v4.set(opts[3])
    
            if index == len(options) - 1:
                button_next['text'] = 'Check the Results'
    
    
    displayNextQuestion()
    root.mainloop()
#-----------------------------------------------------------------------------------------------------------------------------------------------------

def Quiz1():
    global index,correct
    root = tk.Tk()
    root.geometry('500x500')
    
    questions = ["How is an array initialized in C language?",
                 "Which of the following is not a logical operator?",
                 "Which of these keywords is not a part of exception handling?",
                 "What is the name of the method used to start a thread execution?",
                 "_______ is the process of finding errors and fixing them within a program."]
    
    
    options = [[' int [] arr = new int[5]','int arr[] = {1,2,3,4,5}','int arr[] = new int[5]','int arr[] = int [5] new','int arr[] = {1,2,3,4,5}'],
               ['&&','||','!','|','|'],
               ['Finally','Thrown','Catch','Try','Thrown'],
               ['run();','init();','start();','resume();','start();'],
               ['Compiling','Executing','Debugging','Scaning','Debugging']]


    frame = tk.Frame(root, padx=10, pady=10,bg='#fff')
    question_label = tk.Label(frame,height=5, width=28,bg='grey',fg="#fff", 
                              font=('Verdana', 20),wraplength=500)
    
    
    v1 = StringVar(frame)
    v2 = StringVar(frame)
    v3 = StringVar(frame)
    v4 = StringVar(frame)

    option1 = tk.Radiobutton(frame, bg="#fff", variable=v1, font=('Verdana', 20),
                             command = lambda : checkAnswer(option1))
    option2 = tk.Radiobutton(frame, bg="#fff", variable=v2, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option2))
    option3 = tk.Radiobutton(frame, bg="#fff", variable=v3, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option3))
    option4 = tk.Radiobutton(frame, bg="#fff", variable=v4, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option4))
    
    button_next = tk.Button(frame, text='Next',bg='green', font=('Verdana', 20), 
                            command = lambda : displayNextQuestion())
    
    frame.pack(fill="both", expand="true")
    question_label.grid(row=0, column=0)
    
    option1.grid(sticky= 'W', row=1, column=0)
    option2.grid(sticky= 'W', row=2, column=0)
    option3.grid(sticky= 'W', row=3, column=0)
    option4.grid(sticky= 'W', row=4, column=0)
    
    button_next.grid(row=6, column=0)

    
    index = 0
    correct = 0
    
    # create a function to disable radiobuttons
    def disableButtons(state):
        option1['state'] = state
        option2['state'] = state
        option3['state'] = state
        option4['state'] = state
    
    
    # create a function to check the selected answer
    def checkAnswer(radio):
        global correct, index
        
        # the 4th item is the correct answer
        # we will check the user selected answer with the 4th item
        if radio['text'] == options[index][4]:
            correct +=1
    
        index +=1
        disableButtons('disable')
    
    
    # create a function to display the next question
    def displayNextQuestion():
        global index, correct
    
        if button_next['text'] == 'Restart The Quiz':
            correct = 0
            index = 0
            question_label['bg'] = 'grey'
            button_next['text'] = 'Next'
    
        if index == len(options):
           question_label['text'] = str(correct) + " / " + str(len(options))
           button_next['text'] = 'Restart The Quiz'
           if correct >= len(options)/2:
               question_label['bg'] = 'green'
           else:
                question_label['bg'] = 'red'
    
        else:
            question_label['text'] = questions[index]
            
            disableButtons('normal')
            opts = options[index]
            option1['text'] = opts[0]
            option2['text'] = opts[1]
            option3['text'] = opts[2]
            option4['text'] = opts[3]
            v1.set(opts[0])
            v2.set(opts[1])
            v3.set(opts[2])
            v4.set(opts[3])
    
            if index == len(options) - 1:
                button_next['text'] = 'Check the Results'
    
    
    
    
    
    displayNextQuestion()
    
    root.mainloop()

#-------------------------------------------------------------------------------------------------------------------------------------------------


def Quiz2():
    global index,correct
    root = tk.Tk()
    root.geometry('500x500')
    
    questions = ["MS-Word is an example of _____",
                 "The paintings in the Ajanta and Ellora caves are indicative of the development of art under the ______",
                 "Classical dance 'Mohiniattam' belongs to which state?",
                 " 1 Joule is Equal to?",
                 "The first Indian to receive Nobel Prize in Literature was "]
    
    
    options = [['An operating system','A processing device','Application software','An input device','Application software'],
               ['Pallavas','Chalukyas','Pandyas','Rashtrakutas','Chalukyas'],
               ['Tamilnadu','Andhra Pradesh','Manipur','Kerala','Kerala'],
               ['10^3 ergs','10^6 ergs','10^7 ergs','10^5 ergs','10^7 ergs'],
               ['Mother Teresa','Rabindranath Tagore','Sarojini Naidu','C.V.Raman','Mother Teresa']]
    
    
    frame = tk.Frame(root, padx=10, pady=10,bg='#fff')
    question_label = tk.Label(frame,height=5, width=28,bg='grey',fg="#fff", 
                              font=('Verdana', 20),wraplength=500)
    
    
    v1 = StringVar(frame)
    v2 = StringVar(frame)
    v3 = StringVar(frame)
    v4 = StringVar(frame)
    
    option1 = tk.Radiobutton(frame, bg="#fff", variable=v1, font=('Verdana', 20),
                             command = lambda : checkAnswer(option1))
    option2 = tk.Radiobutton(frame, bg="#fff", variable=v2, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option2))
    option3 = tk.Radiobutton(frame, bg="#fff", variable=v3, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option3))
    option4 = tk.Radiobutton(frame, bg="#fff", variable=v4, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option4))
    
    button_next = tk.Button(frame, text='Next',bg='yellow', font=('Verdana', 20), 
                            command = lambda : displayNextQuestion())
    
    frame.pack(fill="both", expand="true")
    question_label.grid(row=0, column=0)
    
    option1.grid(sticky= 'W', row=1, column=0)
    option2.grid(sticky= 'W', row=2, column=0)
    option3.grid(sticky= 'W', row=3, column=0)
    option4.grid(sticky= 'W', row=4, column=0)
    
    button_next.grid(row=6, column=0)
    
    
    index = 0
    correct = 0
    
    # create a function to disable radiobuttons
    def disableButtons(state):
        option1['state'] = state
        option2['state'] = state
        option3['state'] = state
        option4['state'] = state
    
    # create a function to check the selected answer
    def checkAnswer(radio):
        global correct,index
        
        # the 4th item is the correct answer
        # we will check the user selected answer with the 4th item
        if radio['text'] == options[index][4]:
            correct +=1
    
        index +=1
        disableButtons('disable')
    
    
    # create a function to display the next question
    def displayNextQuestion():
        global index,correct
    
        if button_next['text'] == 'Restart The Quiz':
            correct = 0
            index = 0
            question_label['bg'] = 'grey'
            button_next['text'] = 'Next'
    
        if index == len(options):
           question_label['text'] = str(correct) + " / " + str(len(options))
           button_next['text'] = 'Restart The Quiz'
           if correct >= len(options)/2:
               question_label['bg'] = 'green'
           else:
                question_label['bg'] = 'red'
    
        else:
            question_label['text'] = questions[index]
            
            disableButtons('normal')
            opts = options[index]
            option1['text'] = opts[0]
            option2['text'] = opts[1]
            option3['text'] = opts[2]
            option4['text'] = opts[3]
            v1.set(opts[0])
            v2.set(opts[1])
            v3.set(opts[2])
            v4.set(opts[3])
    
            if index == len(options) - 1:
                button_next['text'] = 'Check the Results'
    
    
    displayNextQuestion()
    root.mainloop()
    
#------------------------------------------------------------------------------------------------------------------------------------------------

def Quiz3():
    global index,correct
    root = tk.Tk()
    root.geometry('500x500')
    
    questions = ["The term “Tee” is used commonly in which among the following sports?",
                 "For how many times ” Undivided India” was part / member of summer Olympics?",
                 "Who among the following was known as Flying Sikh?",
                 "In which year, the first-ever cricket test match took place?",
                 " India won its first Olympic hockey gold in..."]
    
    
    options = [['Tennis','Polo','Golf','Racing','Golf'],
               ['2','3','4','5','5'],
               [' Milkha Singh','Harbhajan Singh','Yuvaraj Singh','Gurbachan Singh','Milkha Singh'],
               ['1875','1877','1879','1881','1877'],
               ['1924','1932','1928','1948','1928']]
    
    
    frame = tk.Frame(root, padx=10, pady=10,bg='#fff')
    question_label = tk.Label(frame,height=5, width=28,bg='grey',fg="#fff", 
                              font=('Verdana', 20),wraplength=500)
    
    
    v1 = StringVar(frame)
    v2 = StringVar(frame)
    v3 = StringVar(frame)
    v4 = StringVar(frame)
    
    option1 = tk.Radiobutton(frame, bg="#fff", variable=v1, font=('Verdana', 20),
                             command = lambda : checkAnswer(option1))
    option2 = tk.Radiobutton(frame, bg="#fff", variable=v2, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option2))
    option3 = tk.Radiobutton(frame, bg="#fff", variable=v3, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option3))
    option4 = tk.Radiobutton(frame, bg="#fff", variable=v4, font=('Verdana', 20), 
                             command = lambda : checkAnswer(option4))
    
    button_next = tk.Button(frame, text='Next',bg='yellow', font=('Verdana', 20), 
                            command = lambda : displayNextQuestion())
    
    frame.pack(fill="both", expand="true")
    question_label.grid(row=0, column=0)
    
    option1.grid(sticky= 'W', row=1, column=0)
    option2.grid(sticky= 'W', row=2, column=0)
    option3.grid(sticky= 'W', row=3, column=0)
    option4.grid(sticky= 'W', row=4, column=0)
    
    button_next.grid(row=6, column=0)
    
    
    index = 0
    correct = 0
    
    # create a function to disable radiobuttons
    def disableButtons(state):
        option1['state'] = state
        option2['state'] = state
        option3['state'] = state
        option4['state'] = state
    
    # create a function to check the selected answer
    def checkAnswer(radio):
        global correct, index
        
        # the 4th item is the correct answer
        # we will check the user selected answer with the 4th item
        if radio['text'] == options[index][4]:
            correct +=1
    
        index +=1
        disableButtons('disable')
    
    
    # create a function to display the next question
    def displayNextQuestion():
        global index, correct
    
        if button_next['text'] == 'Restart The Quiz':
            correct = 0
            index = 0
            question_label['bg'] = 'grey'
            button_next['text'] = 'Next'
    
        if index == len(options):
           question_label['text'] = str(correct) + " / " + str(len(options))
           button_next['text'] = 'Restart The Quiz'
           if correct >= len(options)/2:
               question_label['bg'] = 'green'
           else:
                question_label['bg'] = 'red'
    
        else:
            question_label['text'] = questions[index]
            
            disableButtons('normal')
            opts = options[index]
            option1['text'] = opts[0]
            option2['text'] = opts[1]
            option3['text'] = opts[2]
            option4['text'] = opts[3]
            v1.set(opts[0])
            v2.set(opts[1])
            v3.set(opts[2])
            v4.set(opts[3])
    
            if index == len(options) - 1:
                button_next['text'] = 'Check the Results'
    
    
    displayNextQuestion()
    

#--------------------------------------------------------------------------------------------------------------------------------------------------
def clicked():
    def click():
        name = txt.get()
        Age = txt1.get()
        phone = txt2.get()
        email = txt3.get()
        password = txt4.get()
        connection = sqlite3.connect("Resgistration.db")
        crsr = connection.cursor()
        if(name == "" and Age == "" and phone == ""  and email == "" and password == "" ):
            messagebox.showinfo("Incomplete Data","Please fill the complete data")
        else:
            crsr.execute(""" INSERT INTO RPT(name,Age,Phone_NO,Email_id,Password) VALUES(?,?,?,?,?);""",(name,Age,phone,email,password))
            messagebox.showinfo('Successfull','Data inserted')
            connection.commit()
            connection.close()
            clear()
    def login():
        def register():
             new_window = Tk()
             new_window .title("Register Here")
             new_window .geometry('550x500')
             new_window.configure(bg="#ADE9DB")
             login_window.withdraw()
             lbl = Label(new_window  , text = "Register Here for Tourism Quiz " ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
             lbl.place(x = 60 , y =5 )
             lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place (x = 80 , y = 80)
             txt = Entry(new_window ,width=30)
             txt.place (x = 200 , y = 80)
                
             lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 120)
             txt1 = Entry(new_window ,width=30)
             txt1.place(x = 200 , y = 120)
            
             lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 160)
             txt2 = Entry(new_window ,width=30)
             txt2.place(x = 200 , y = 160)
            
             lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 200)
             txt3 = Entry(new_window ,width=30)
             txt3.place(x = 200 , y = 200)
            
             lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 240)
             txt4 = Entry(new_window ,width=30,show="*")
             txt4.place(x = 200 , y = 240)
            
             btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0)
             btn.place(x = 190 , y = 300)
             btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0)
             btn1.place(x = 280 , y = 300)
            
             new_window.mainloop()
            
        def compare():
            user = txt.get()
            password = txt1.get()
            connection = sqlite3.connect("Resgistration.db")
            crsr = connection.cursor()
            crsr.execute("SELECT name, Password FROM RPT")
            ans = crsr.fetchall()
            for i in ans:
                if(user == '' and password == ''):
                    messagebox.showinfo('Please ','Please fill all the fileds')
                elif(str(i[0]) == str(user) and str(i[1] == str(password))):
                    next_window = Tk()
                    next_window.title("Susseccfully Login")
                    next_window.geometry('200x200')
                    login_window.withdraw()
                    lbl = Label(next_window , text = "You are succesfully logined" , font = ("Arial Bold", 10))
                    lbl.place(x = 10, y =5 )
                    btn=Button(next_window,text = "Start Quiz" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = Quiz)
                    btn.place(x = 50, y = 50)
                    break
                else:
                    messagebox.showinfo('Login Failure','User does not exsist ! Please Resgister first')
            
            
        login_window = Tk()
        login_window.title("Login Here Please")
        login_window.geometry('400x400')
        login_window.resizable(False, False)
        new_window.withdraw()
        lbl = Label(login_window , text = "Login In" , font = ("Arial Bold", 20))
        lbl.place(x = 150 , y =5 )
        lbl = Label(login_window , text = "username" , font = ("Arial Bold", 10))
        lbl.place (x = 50 , y = 60)
        txt = Entry(login_window,width=30)
        txt.place (x = 150 , y = 60)
        
        lbl = Label(login_window , text = "password" , font = ("Arial Bold", 10))
        lbl.place(x = 50 , y = 90)
        txt1 = Entry(login_window,width=30,show="*")
        txt1.place(x = 150 , y = 90)
        
        btn=Button(login_window ,text = "Login in" , bg="#49ad67" , fg = "white" , font = ("Arial Bold", 10) ,borderwidth = 0 , command = compare)
        btn.place(x = 100 , y = 150)
        
        btn=Button(login_window ,text = "Create account" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = register)
        btn.place(x = 200 , y = 150)
        
        window.mainloop()
        
    new_window = Tk()
    new_window.title("Register Here")
    new_window.geometry('550x500')
    new_window.configure(bg="#ADE9DB")
    window.withdraw()
    lbl = Label(new_window  , text = "Register Here for Tourism Quiz" ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
    lbl.place(x = 60 , y =5 )
    lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place (x = 80 , y = 80)
    txt = Entry(new_window ,width=30)
    txt.place (x = 200 , y = 80)
    
    lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 120)
    txt1 = Entry(new_window ,width=30)
    txt1.place(x = 200 , y = 120)
    
    lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 160)
    txt2 = Entry(new_window ,width=30)
    txt2.place(x = 200 , y = 160)
    
    lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 200)
    txt3 = Entry(new_window ,width=30)
    txt3.place(x = 200 , y = 200)
    
    lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 240)
    txt4 = Entry(new_window ,width=30,show="*")
    txt4.place(x = 200 , y = 240)

    btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10), borderwidth= 0 , command = click)
    btn.place(x = 190 , y = 300)
    btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth= 0 , command = login)
    btn1.place(x = 280 , y = 300)
    
    new_window.mainloop()
# ------------------------------------------------------------------------------------------------------------------------------------------------
def clicked1():
    def click():
        name = txt.get()
        Age = txt1.get()
        phone = txt2.get()
        email = txt3.get()
        password = txt4.get()
        connection = sqlite3.connect("Resgistration.db")
        crsr = connection.cursor()
        if(name == "" and Age == "" and phone == ""  and email == "" and password == "" ):
            messagebox.showinfo("Incomplete Data","Please fill the complete data")
        else:
            crsr.execute(""" INSERT INTO RT(name,Age,Phone_NO,Email_id,Password) VALUES(?,?,?,?,?);""",(name,Age,phone,email,password))
            messagebox.showinfo('Successfull','Data inserted')
            connection.commit()
            connection.close()
    def login():
        def register():
             new_window = Tk()
             new_window .title("Register Here")
             new_window .geometry('550x500')
             new_window.configure(bg="#ADE9DB")
             login_window.withdraw()
             lbl = Label(new_window  , text = "Register Here for Coding Assessment" ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
             lbl.place(x = 60 , y =5 )
             lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place (x = 80 , y = 80)
             txt = Entry(new_window ,width=30)
             txt.place (x = 200 , y = 80)
                
             lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 120)
             txt1 = Entry(new_window ,width=30)
             txt1.place(x = 200 , y = 120)
            
             lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 160)
             txt2 = Entry(new_window ,width=30)
             txt2.place(x = 200 , y = 160)
            
             lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 200)
             txt3 = Entry(new_window ,width=30)
             txt3.place(x = 200 , y = 200)
            
             lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 240)
             txt4 = Entry(new_window ,width=30,show="*")
             txt4.place(x = 200 , y = 240)
            
             btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0)
             btn.place(x = 190 , y = 300)
             btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0)
             btn1.place(x = 280 , y = 300)
            
             new_window.mainloop()
            
        def compare():
            user = txt.get()
            password = txt1.get()
            connection = sqlite3.connect("Resgistration.db")
            crsr = connection.cursor()
            crsr.execute("SELECT name, Password FROM RT")
            ans = crsr.fetchall()
            for i in ans:
                if(user == '' and password == ''):
                    messagebox.showinfo('Please ','Please fill all the fileds')
                elif(str(i[0]) == str(user) and str(i[1] == str(password))):
                    next_window = Tk()
                    next_window.title("Susseccfully Login")
                    next_window.geometry('200x200')
                    login_window.withdraw()
                    lbl = Label(next_window , text = "You are succesfully logined" , font = ("Arial Bold", 10))
                    lbl.place(x = 10, y =5 )
                    btn=Button(next_window,text = "Start Quiz" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = Quiz1)
                    btn.place(x = 50, y = 50)
                    break
                else:
                    messagebox.showinfo('Login Failure','User does not exsist ! Please Resgister first')
            
            
        login_window = Tk()
        login_window.title("Login Here Please")
        login_window.geometry('400x400')
        login_window.resizable(False, False)
        new_window.withdraw()
        lbl = Label(login_window , text = "Login In" , font = ("Arial Bold", 20))
        lbl.place(x = 150 , y =5 )
        lbl = Label(login_window , text = "username" , font = ("Arial Bold", 10))
        lbl.place (x = 50 , y = 60)
        txt = Entry(login_window,width=30)
        txt.place (x = 150 , y = 60)
        
        lbl = Label(login_window , text = "password" , font = ("Arial Bold", 10))
        lbl.place(x = 50 , y = 90)
        txt1 = Entry(login_window,width=30,show="*")
        txt1.place(x = 150 , y = 90)
        
        btn=Button(login_window ,text = "Login in" , bg="#49ad67" , fg = "white" , font = ("Arial Bold", 10) ,borderwidth = 0 , command = compare)
        btn.place(x = 100 , y = 150)
        
        btn=Button(login_window ,text = "Create account" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = register)
        btn.place(x = 200 , y = 150)
        
        window.mainloop()
    
            
    new_window = Tk()
    new_window .title("Register Here")
    new_window .geometry('550x500')
    new_window.configure(bg="#ADE9DB")
    window.withdraw()
    lbl = Label(new_window  , text = "Register Here for Coding Assessment" ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
    lbl.place(x = 60 , y =5 )
    lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place (x = 80 , y = 80)
    txt = Entry(new_window ,width=30)
    txt.place (x = 200 , y = 80)
    
    lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 120)
    txt1 = Entry(new_window ,width=30)
    txt1.place(x = 200 , y = 120)

    lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 160)
    txt2 = Entry(new_window ,width=30)
    txt2.place(x = 200 , y = 160)
    
    lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 200)
    txt3 = Entry(new_window ,width=30)
    txt3.place(x = 200 , y = 200)
    
    lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 240)
    txt4 = Entry(new_window ,width=30,show="*")
    txt4.place(x = 200 , y = 240)
    
    btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = click)
    btn.place(x = 190 , y = 300)
    btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = login)
    btn1.place(x = 280 , y = 300)
    
    new_window.mainloop()

# --------------------------------------------------------------------------------------------------------------------------------------------------
def clicked2():
    def click():
        name = txt.get()
        Age = txt1.get()
        phone = txt2.get()
        email = txt3.get()
        password = txt4.get()
        connection = sqlite3.connect("Resgistration.db")
        crsr = connection.cursor()
        if(name == "" and Age == "" and phone == ""  and email == "" and password == "" ):
            messagebox.showinfo("Incomplete Data","Please fill the complete data")
        else:
            crsr.execute(""" INSERT INTO RGK(name,Age,Phone_NO,Email_id,Password) VALUES(?,?,?,?,?);""",(name,Age,phone,email,password))
            messagebox.showinfo('Successfull','Data inserted')
            connection.commit()
            connection.close()
    def login():
        def register():
             new_window = Tk()
             new_window .title("Register Here")
             new_window .geometry('550x500')
             new_window.configure(bg="#ADE9DB")
             login_window.withdraw()
             lbl = Label(new_window  , text = "Register Here for Gk Test" ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
             lbl.place(x = 60 , y =5 )
             lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place (x = 80 , y = 80)
             txt = Entry(new_window ,width=30)
             txt.place (x = 200 , y = 80)
                
             lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 120)
             txt1 = Entry(new_window ,width=30)
             txt1.place(x = 200 , y = 120)
            
             lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 160)
             txt2 = Entry(new_window ,width=30)
             txt2.place(x = 200 , y = 160)
            
             lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 200)
             txt3 = Entry(new_window ,width=30)
             txt3.place(x = 200 , y = 200)
            
             lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 240)
             txt4 = Entry(new_window ,width=30,show="*")
             txt4.place(x = 200 , y = 240)
            
             btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0, )
             btn.place(x = 190 , y = 300)
             btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 )
             btn1.place(x = 280 , y = 300)
            
             new_window.mainloop()
            
        def compare():
            user = txt.get()
            password = txt1.get()
            connection = sqlite3.connect("Resgistration.db")
            crsr = connection.cursor()
            crsr.execute("SELECT name, Password FROM RGK")
            ans = crsr.fetchall()
            for i in ans:
                if(user == '' and password == ''):
                    messagebox.showinfo('Please ','Please fill all the fileds')
                elif(str(i[0]) == str(user) and str(i[1] == str(password))):
                    next_window = Tk()
                    next_window.title("Susseccfully Login")
                    next_window.geometry('200x200')
                    login_window.withdraw()
                    lbl = Label(next_window , text = "You are succesfully logined" , font = ("Arial Bold", 10))
                    lbl.place(x = 10, y =5 )
                    btn=Button(next_window,text = "Start Quiz" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = Quiz2)
                    btn.place(x = 50, y = 50)
                    break
                else:
                    messagebox.showinfo('Login Failure','User does not exsist ! Please Resgister first')
            
            
        login_window = Tk()
        login_window.title("Login Here Please")
        login_window.geometry('400x400')
        login_window.resizable(False, False)
        new_window.withdraw()
        lbl = Label(login_window , text = "Login In" , font = ("Arial Bold", 20))
        lbl.place(x = 150 , y =5 )
        lbl = Label(login_window , text = "username" , font = ("Arial Bold", 10))
        lbl.place (x = 50 , y = 60)
        txt = Entry(login_window,width=30)
        txt.place (x = 150 , y = 60)
        
        lbl = Label(login_window , text = "password" , font = ("Arial Bold", 10))
        lbl.place(x = 50 , y = 90)
        txt1 = Entry(login_window,width=30,show="*")
        txt1.place(x = 150 , y = 90)
        
        btn=Button(login_window ,text = "Login in" , bg="#49ad67" , fg = "white" , font = ("Arial Bold", 10) ,borderwidth = 0 , command = compare)
        btn.place(x = 100 , y = 150)
        
        btn=Button(login_window ,text = "Create account" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = register)
        btn.place(x = 200 , y = 150)
        
        window.mainloop()
    
    
    new_window = Tk()
    new_window .title("Register Here")
    new_window .geometry('550x500')
    new_window.configure(bg="#ADE9DB")
    window.withdraw()
    lbl = Label(new_window  , text = "Register Here for Gk Test" ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
    lbl.place(x = 60 , y =5 )
    lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place (x = 80 , y = 80)
    txt = Entry(new_window ,width=30)
    txt.place (x = 200 , y = 80)
    
    lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 120)
    txt1 = Entry(new_window ,width=30)
    txt1.place(x = 200 , y = 120)

    lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 160)
    txt2 = Entry(new_window ,width=30)
    txt2.place(x = 200 , y = 160)
    
    lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 200)
    txt3 = Entry(new_window ,width=30)
    txt3.place(x = 200 , y = 200)
    
    lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 240)
    txt4 = Entry(new_window ,width=30,show="*")
    txt4.place(x = 200 , y = 240)
    
    btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 ,command = click)
    btn.place(x = 190 , y = 300)
    btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0, command = login)
    btn1.place(x = 280 , y = 300)
    
    new_window.mainloop()

#--------------------------------------------------------------------------------------------------------------------------------
def clicked3():
    def click():
        name = txt.get()
        Age = txt1.get()
        phone = txt2.get()
        email = txt3.get()
        password = txt4.get()
        connection = sqlite3.connect("Resgistration.db")
        crsr = connection.cursor()
        if(name == "" and Age == "" and phone == ""  and email == "" and password == "" ):
            messagebox.showinfo("Incomplete Data","Please fill the complete data")
        else:
            crsr.execute(""" INSERT INTO RST(name,Age,Phone_NO,Email_id,Password) VALUES(?,?,?,?,?);""",(name,Age,phone,email,password))
            messagebox.showinfo('Successfull','Data inserted')
            connection.commit()
            connection.close()
    def login():
        def register():
             new_window = Tk()
             new_window .title("Register Here")
             new_window .geometry('550x500')
             new_window.configure(bg="#ADE9DB")
             login_window.withdraw()
             lbl = Label(new_window  , text = "Register Here for Sports Quiz " ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
             lbl.place(x = 60 , y =5 )
             lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place (x = 80 , y = 80)
             txt = Entry(new_window ,width=30)
             txt.place (x = 200 , y = 80)
                
             lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 120)
             txt1 = Entry(new_window ,width=30)
             txt1.place(x = 200 , y = 120)
            
             lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 160)
             txt2 = Entry(new_window ,width=30)
             txt2.place(x = 200 , y = 160)
            
             lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 200)
             txt3 = Entry(new_window ,width=30)
             txt3.place(x = 200 , y = 200)
            
             lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
             lbl.place(x = 80 , y = 240)
             txt4 = Entry(new_window ,width=30,show="*")
             txt4.place(x = 200 , y = 240)
            
             btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0, )
             btn.place(x = 190 , y = 300)
             btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 )
             btn1.place(x = 280 , y = 300)
            
             new_window.mainloop()
            
        def compare():
            user = txt.get()
            password = txt1.get()
            connection = sqlite3.connect("Resgistration.db")
            crsr = connection.cursor()
            crsr.execute("SELECT name, Password FROM RST")
            ans = crsr.fetchall()
            for i in ans:
                if(user == '' and password == ''):
                    messagebox.showinfo('Please ','Please fill all the fileds')
                elif(str(i[0]) == str(user) and str(i[1] == str(password))):
                    next_window = Tk()
                    next_window.title("Susseccfully Login")
                    next_window.geometry('200x200')
                    login_window.withdraw()
                    lbl = Label(next_window , text = "You are succesfully logined" , font = ("Arial Bold", 10))
                    lbl.place(x = 10, y =5 )
                    btn=Button(next_window,text = "Start Quiz" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = Quiz3)
                    btn.place(x = 50, y = 50)
                    break
                else:
                    messagebox.showinfo('Login Failure','User does not exsist ! Please Resgister first')
            
            
        login_window = Tk()
        login_window.title("Login Here Please")
        login_window.geometry('400x400')
        login_window.resizable(False, False)
        new_window.withdraw()
        lbl = Label(login_window , text = "Login In" , font = ("Arial Bold", 20))
        lbl.place(x = 150 , y =5 )
        lbl = Label(login_window , text = "username" , font = ("Arial Bold", 10))
        lbl.place (x = 50 , y = 60)
        txt = Entry(login_window,width=30)
        txt.place (x = 150 , y = 60)
        
        lbl = Label(login_window , text = "password" , font = ("Arial Bold", 10))
        lbl.place(x = 50 , y = 90)
        txt1 = Entry(login_window,width=30,show="*")
        txt1.place(x = 150 , y = 90)
        
        btn=Button(login_window ,text = "Login in" , bg="#49ad67" , fg = "white" , font = ("Arial Bold", 10) ,borderwidth = 0 , command = compare)
        btn.place(x = 100 , y = 150)
        
        btn=Button(login_window ,text = "Create account" ,bg="#3a3275" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = register)
        btn.place(x = 200 , y = 150)
        
        window.mainloop()
    
    new_window = Tk()
    new_window .title("Register Here")
    new_window .geometry('550x500')
    new_window.configure(bg="#ADE9DB")
    window.withdraw()
    lbl = Label(new_window  , text = "Register Here for Sports Quiz" ,background= "#ADE9DB",foreground = "white", font = ("Arial Bold", 20))
    lbl.place(x = 60 , y =5 )
    lbl = Label(new_window  , text = "Name" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place (x = 80 , y = 80)
    txt = Entry(new_window ,width=30)
    txt.place (x = 200 , y = 80)
    
    lbl = Label(new_window  , text = "Age" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 120)
    txt1 = Entry(new_window ,width=30)
    txt1.place(x = 200 , y = 120)

    lbl = Label(new_window  , text = "Phone_No" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 160)
    txt2 = Entry(new_window ,width=30)
    txt2.place(x = 200 , y = 160)
    
    lbl = Label(new_window  , text = "Email_id" , background = "#ADE9DB" ,foreground = "white",font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 200)
    txt3 = Entry(new_window ,width=30)
    txt3.place(x = 200 , y = 200)
    
    lbl = Label(new_window  , text = "Password" , background = "#ADE9DB" ,foreground = "white", font = ("Arial Bold", 15))
    lbl.place(x = 80 , y = 240)
    txt4 = Entry(new_window ,width=30,show="*")
    txt4.place(x = 200 , y = 240)
    
    btn=Button(new_window  ,text = "Register" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = click)
    btn.place(x = 190 , y = 300)
    btn1=Button(new_window  ,text = "Login" ,bg="#4482cf" , fg = "white" , font = ("Arial Bold", 10) , borderwidth = 0 , command = login)
    btn1.place(x = 280 , y = 300)
    
    new_window.mainloop()
    
lb = Label(window,text ="Welcome to the World of Quiz" , background = "#9AD7A4" , foreground = "White" , font = ("Arial Bold",20))
lb.place(x = 60 , y=20)
btn = Button(window,text="Tourism Quiz" , bg="#b3e3c7" , borderwidth =0 , fg = "white" , font = ("Arial Bold",15) ,command = clicked)
btn.place(x = 170 , y=100)
btn1 = Button(window, text = "Coding Assessment", bg="#b3e3c7" , borderwidth =0 , fg = "white" , font = ("Arial Bold",15),command = clicked1)
btn1.place(x= 170 , y = 170)
btn2 = Button(window , text = "Gk Test", bg="#b3e3c7" , borderwidth =0 , fg = "white" , font = ("Arial Bold",15),command = clicked2)
btn2.place (x = 170 , y = 240)
btn3 = Button(window , text = "Sports Quiz" , bg="#b3e3c7" , borderwidth =0 , fg = "white" , font = ("Arial Bold",15) , command = clicked3)
btn3.place (x = 170 , y = 310)
window.mainloop()

# %%
# -------------------------------------Above code is the main project for python----------------------------------------------
